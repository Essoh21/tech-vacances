# %%
x= 5
print(type(x))
y = 6.3
print(type(y))
nom = "Léon"
print(type(nom))
valeur = 0.1 +0.2
print(round(valeur , 2))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# 0.3

# %%
a = 5
b = 25
print(a == b)
print(a < b)
print(a > b)
print(a != b)
# Out:
# False
# True
# False
# True

# %%
def enter_in_the_class(age) : 
    
    print("Please how old are you ?")
age = 20
    if (age < 20) :
        print("You cannot have access")
    elif age >= 20 :
            print("You can have access")
    else :
            print("Please enter your age")
# Out:
#   Cell In[41], line 4
#     if (age < 20) :
#     ^
# IndentationError: unexpected indent

# %%
les_noms = ["Ramdane", "Nicolas", "Jean", "Marie"]
if "Léon" in les_noms :
    print("Il est parmi eux")
else:
    print("acces refuse")
# Out:
# acces refuse
